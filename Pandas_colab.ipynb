# %% [markdown]
# <a href="https://colab.research.google.com/github/hemangi2204/Data_science/blob/main/Pandas_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Data Manipulation Library
import pandas as pd
import numpy as np
#Import Data Visualization Library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define a Series : 1D Array

a = pd.Series([1,2,3,4,5])
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(a)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# Using concept of Indexing
a
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
a.dtype
# Out:
# dtype('int64')

# %%
print(a.dtype)
print(a[3])
print(a['d'])
# Out:
# int64
# 4
# 4
# <ipython-input-6-8a239139a59e>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(a[3])

# %%
# 2D

c = pd.DataFrame({'India':[2000],'USA':[3000],'UK':[30000]})
print(c)
# Out:
#    India   USA     UK
# 0   2000  3000  30000

# %%
# Create Student Database
database = {'Name':['Nikhil','Aniket','Mihir','Tanvi','Hemangi'],
            'Age' :[10,11,12,13,14],
            'Marks' :[34,56,67,34,56],
            'CGPA' :[8,6,9,6,8]
            }
# Create a variable df : which will store dataframe
df = pd.DataFrame(database)
print(df)
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df[df['Name'] == 'Tanvi']
# Out:
#     Name  Age  Marks  CGPA
# 3  Tanvi   13     34     6

# %%
df[df['Name'] == 'Hemangi']
# Out:
#       Name  Age  Marks  CGPA
# 4  Hemangi   14     56     8

# %%
#Using agg() : Aggregate Function
df['Marks'].agg(['min','max','mean'])
# Out:
# min     34.0
# max     67.0
# mean    49.4
# Name: Marks, dtype: float64

# %%
df[df['Marks'] == 67]
# Out:
#     Name  Age  Marks  CGPA
# 2  Mihir   12     67     9

# %%
df[df['CGPA'] == 6]
# Out:
#      Name  Age  Marks  CGPA
# 1  Aniket   11     56     6
# 3   Tanvi   13     34     6

# %%
# Checking DataFrame Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      int64
#  3   CGPA    5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
# This code will check if any missing values in dataset

df.isnull().sum()
# Out:
# Name     0
# Age      0
# Marks    0
# CGPA     0
# dtype: int64

# %%
print(df['Marks'].sum())
print(df['Marks'].mean())
print(df['Marks'].median())
print(df['Marks'].min())
print(df['Marks'].max())
print(df['Marks'].nunique())
print(df['Marks'].unique())
print(df['Marks'].value_counts())
print(df['Name'].value_counts())
# Out:
# 247
# 49.4
# 56.0
# 34
# 67
# 3
# [34 56 67]
# Marks
# 34    2
# 56    2
# 67    1
# Name: count, dtype: int64
# Name
# Nikhil     1
# Aniket     1
# Mihir      1
# Tanvi      1
# Hemangi    1
# Name: count, dtype: int64

# %%
print(df['Marks'].value_counts().plot(kind = 'barh'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df['Marks'].value_counts().plot(kind = 'pie'))
# Out:
# Axes(0.22375,0.11;0.5775x0.77)

# %%
database = {'Name':['Siya','Riya','Mai','Ram','Shaym','Disha','Hemangi'],
            'Salary':[10000,20000,30000,40000,50000,60000,70000],
            'No_of_exp':[0,1,2,3,4,5,6],
            'Domain':['Tech','Tech','Tech','NonTech','NonTech','RND','HR'],
            'Age':[20,21,22,23,24,25,26],
            'Gender':['F','F','F','M','M','F','F']
            }
df = pd.DataFrame(database)
print(df)
# Out:
#       Name  Salary  No_of_exp   Domain  Age Gender
# 0     Siya   10000          0     Tech   20      F
# 1     Riya   20000          1     Tech   21      F
# 2      Mai   30000          2     Tech   22      F
# 3      Ram   40000          3  NonTech   23      M
# 4    Shaym   50000          4  NonTech   24      M
# 5    Disha   60000          5      RND   25      F
# 6  Hemangi   70000          6       HR   26      F

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       7 non-null      object
#  1   Salary     7 non-null      int64
#  2   No_of_exp  7 non-null      int64
#  3   Domain     7 non-null      object
#  4   Age        7 non-null      int64
#  5   Gender     7 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 468.0+ bytes

# %%
# max no of dataset
print(df['No_of_exp'].max())
print(df['No_of_exp'].min())
print(df['No_of_exp'].mean())
# Out:
# 6
# 0
# 3.0

# %%
a = df[df['Gender'] == 'F']
print(a)
# Out:
#       Name  Salary  No_of_exp Domain  Age Gender
# 0     Siya   10000          0   Tech   20      F
# 1     Riya   20000          1   Tech   21      F
# 2      Mai   30000          2   Tech   22      F
# 5    Disha   60000          5    RND   25      F
# 6  Hemangi   70000          6     HR   26      F

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    5
# M    2
# Name: count, dtype: int64

# %%
a['Salary'].max()
# Out:
# 70000

# %%
a[a['Salary'] == 70000]
# Out:
#       Name  Salary  No_of_exp Domain  Age Gender
# 6  Hemangi   70000          6     HR   26      F

# %%
'''
Logical Operator in Python Programming
== Comparison Operator
< Less Than operator
> Greater Than operator
<= Less Than or Equal to operator
>= Greater Than or Equal to operator
!= Not Equal to operator
= Assignment operator
And logic operator:&
Or logic operator:|
~ Not logic operator
~ (tilde)/Not operator
'''
# Out:
# '\nLogical Operator in Python Programming \n== Comparison Operator\n< Less Than operator\n> Greater Than operator\n<= Less Than or Equal to operator\n>= Greater Than or Equal to operator\n!= Not Equal to operator\n= Assignment operator\nAnd logic operator:&\nOr logic operator:|\n~ Not logic operator\n~ (tilde)/Not operator\n'

# %%
database = {'Name':['Nikhil','Aniket','Mihir','Tanvi','Hemangi'],
            'Age' :[10,11,12,13,14],
            'Marks' :[34,56,67,34,56],
            'CGPA' :[8,6,9,6,8]
            }
df = pd.DataFrame(database)
print(df)
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df[(df['CGPA']< 8) & (df['Marks']> 30)]
# Out:
#      Name  Age  Marks  CGPA
# 1  Aniket   11     56     6
# 3   Tanvi   13     34     6

# %%
df[(df['CGPA']< 8) | (df['Marks']> 30)]
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df[~(df['CGPA']< 8) | (df['Marks']> 30)]
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
#MATPLOTLIB
#Plotting Bar Plot Using Matplotlib
plt.bar(df['Name'],df['CGPA'],color = 'g')
plt.title('CGPA VS Name')
plt.grid()
plt.ylim(0,5)
plt.show()
